# %% [markdown]
# <a href="https://colab.research.google.com/github/shaid03/Machine-Learning/blob/main/Linear_Regression__Multi_variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import pandas as pd
from sklearn import linear_model

# %%
df = pd.read_csv('/content/data.csv')

# %%
df
# Out:
#    age  height  weight  premium
# 0   25  162.56      70    18000
# 1   30  172.72      95    32000
# 2   35  167.64      78    40000
# 3   40     NaN     110    47000
# 4   45  157.48      85    55000

# %%
# filling missing value
mean_height = df.height.mean()

# %%
mean_height
# Out:
# 165.1

# %%
df.height=df.height.fillna(mean_height)

# %%
df
# Out:
#    age  height  weight  premium
# 0   25  162.56      70    18000
# 1   30  172.72      95    32000
# 2   35  167.64      78    40000
# 3   40  165.10     110    47000
# 4   45  157.48      85    55000

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['age','height','weight']],df['premium'])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([2009.46501319,  501.71220028,  -56.72906086])

# %%
reg.intercept_
# Out:
# -109794.49399687728

# %%
reg.predict([[27,167.56,60]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([25124.21398681])
